# %%
from nltk.book import *
from __future__ import division
import nltk
import numpy
import matplotlib
from nltk import word_tokenize

print('The nltk version is {}.'.format(nltk.__version__))
# Out:
# The nltk version is 3.3.

# %%
sent7 = ['Pierre', 'Vinken', ',', '61', 'years', 'old', ',', 'will', 'join', 'the',
'board', 'as', 'a', 'nonexecutive', 'director', 'Nov.', '29', '.']

# %%
[w for w in sent7 if len(w) < 4]
# Out:
# [',', '61', 'old', ',', 'the', 'as', 'a', '29', '.']

# %%
kalimat = ("Halo, saya sedang belajar machine-learning. " +
            "Saya suka makan apel dan makan sate. ")
elements = word_tokenize(kalimat)

# %%
sorted([ w for w in elements if len(w) > 5])
# Out:
# ['belajar', 'machine-learning', 'sedang']

# %%
sorted([w for w in set(text1) if w.endswith('ableness')])
# Out:
# [u'comfortableness',
#  u'honourableness',
#  u'immutableness',
#  u'indispensableness',
#  u'indomitableness',
#  u'intolerableness',
#  u'palpableness',
#  u'reasonableness',
#  u'uncomfortableness']

# %%
sorted([w for w in set(text7) if '-' in w and 'index' in w])
# Out:
# [u'Stock-index',
#  u'index-arbitrage',
#  u'index-fund',
#  u'index-options',
#  u'index-related',
#  u'stock-index']

# %%
[len(w) for w in text1]
# Out:
# [1,
#  4,
#  4,
#  2,
#  6,
#  8,
#  4,
#  1,
#  9,
#  1,
#  1,
#  8,
#  2,
#  1,
#  4,
#  11,
#  5,
#  2,
#  1,
#  7,
#  6,
#  1,
#  3,
#  4,
#  5,
#  2,
#  10,
#  2,
#  4,
#  1,
#  5,
#  1,
#  4,
#  1,
#  3,
#  5,
#  1,
#  1,
#  3,
#  3,
#  3,
#  1,
#  2,
#  3,
#  4,
#  7,
#  3,
#  3,
#  8,
#  3,
#  8,
#  1,
#  4,
#  1,
#  5,
#  12,
#  1,
#  9,
#  11,
#  4,
#  3,
#  3,
#  3,
#  5,
#  2,
#  3,
#  3,
#  5,
#  7,
#  2,
#  3,
#  5,
#  1,
#  2,
#  5,
#  2,
#  4,
#  3,
#  3,
#  8,
#  1,
#  2,
#  7,
#  6,
#  8,
#  3,
#  2,
#  3,
#  9,
#  1,
#  1,
#  5,
#  3,
#  4,
#  2,
#  4,
#  2,
#  6,
#  6,
#  1,
#  3,
#  2,
#  5,
#  4,
#  2,
#  4,
#  4,
#  1,
#  5,
#  1,
#  4,
#  2,
#  2,
#  2,
#  6,
#  2,
#  3,
#  6,
#  7,
#  3,
#  1,
#  7,
#  9,
#  1,
#  3,
#  6,
#  1,
#  1,
#  5,
#  6,
#  5,
#  6,
#  3,
#  13,
#  2,
#  3,
#  4,
#  1,
#  3,
#  7,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  2,
#  8,
#  1,
#  5,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  1,
#  4,
#  1,
#  4,
#  6,
#  2,
#  5,
#  4,
#  9,
#  2,
#  7,
#  1,
#  3,
#  2,
#  3,
#  1,
#  5,
#  2,
#  6,
#  2,
#  7,
#  2,
#  2,
#  7,
#  1,
#  1,
#  10,
#  1,
#  5,
#  1,
#  3,
#  2,
#  2,
#  4,
#  11,
#  4,
#  3,
#  3,
#  1,
#  3,
#  3,
#  1,
#  6,
#  1,
#  1,
#  1,
#  1,
#  1,
#  4,
#  1,
#  3,
#  1,
#  2,
#  4,
#  1,
#  2,
#  6,
#  2,
#  2,
#  10,
#  1,
#  1,
#  10,
#  5,
#  1,
#  5,
#  1,
#  5,
#  1,
#  5,
#  1,
#  5,
#  1,
#  5,
#  1,
#  5,
#  1,
#  5,
#  1,
#  6,
#  1,
#  3,
#  1,
#  5,
#  1,
#  4,
#  1,
#  7,
#  1,
#  5,
#  1,
#  9,
#  1,
#  5,
#  1,
#  7,
#  1,
#  7,
#  1,
#  6,
#  1,
#  7,
#  1,
#  7,
#  1,
#  5,
#  1,
#  4,
#  1,
#  4,
#  1,
#  5,
#  1,
#  5,
#  1,
#  4,
#  1,
#  4,
#  1,
#  11,
#  1,
#  8,
#  1,
#  8,
#  2,
#  1,
#  3,
#  1,
#  3,
#  1,
#  9,
#  2,
#  2,
#  4,
#  2,
#  4,
#  4,
#  4,
#  4,
#  11,
#  8,
#  3,
#  4,
#  1,
#  4,
#  2,
#  1,
#  4,
#  5,
#  2,
#  1,
#  3,
#  1,
#  3,
#  7,
#  2,
#  4,
#  4,
#  7,
#  3,
#  4,
#  8,
#  3,
#  6,
#  1,
#  6,
#  2,
#  3,
#  5,
#  1,
#  7,
#  2,
#  8,
#  6,
#  9,
#  2,
#  6,
#  2,
#  5,
#  7,
#  4,
#  2,
#  3,
#  4,
#  10,
#  1,
#  6,
#  2,
#  7,
#  1,
#  9,
#  3,
#  4,
#  3,
#  1,
#  2,
#  5,
#  4,
#  2,
#  5,
#  1,
#  4,
#  3,
#  8,
#  1,
#  8,
#  5,
#  10,
#  1,
#  7,
#  9,
#  1,
#  2,
#  5,
#  8,
#  1,
#  3,
#  9,
#  6,
#  8,
#  1,
#  3,
#  4,
#  2,
#  1,
#  2,
#  8,
#  3,
#  7,
#  7,
#  9,
#  1,
#  2,
#  4,
#  2,
#  3,
#  5,
#  4,
#  9,
#  1,
#  5,
#  8,
#  3,
#  6,
#  8,
#  2,
#  12,
#  1,
#  2,
#  9,
#  1,
#  8,
#  4,
#  1,
#  1,
#  3,
#  4,
#  2,
#  4,
#  3,
#  4,
#  13,
#  4,
#  1,
#  7,
#  1,
#  7,
#  1,
#  3,
#  4,
#  2,
#  9,
#  1,
#  2,
#  4,
#  7,
#  3,
#  11,
#  1,
#  9,
#  3,
#  3,
#  1,
#  2,
#  4,
#  4,
#  4,
#  1,
#  4,
#  5,
#  2,
#  1,
#  3,
#  1,
#  3,
#  1,
#  5,
#  11,
#  1,
#  2,
#  1,
#  4,
#  9,
#  2,
#  4,
#  8,
#  1,
#  6,
#  5,
#  5,
#  2,
#  4,
#  2,
#  4,
#  5,
#  4,
#  4,
#  4,
#  1,
#  3,
#  3,
#  4,
#  4,
#  4,
#  6,
#  5,
#  2,
#  3,
#  4,
#  1,
#  6,
#  1,
#  3,
#  4,
#  4,
#  3,
#  9,
#  5,
#  2,
#  3,
#  1,
#  3,
#  4,
#  4,
#  1,
#  8,
#  1,
#  3,
#  1,
#  3,
#  4,
#  9,
#  4,
#  5,
#  1,
#  3,
#  3,
#  2,
#  4,
#  7,
#  1,
#  4,
#  4,
#  4,
#  3,
#  5,
#  7,
#  1,
#  3,
#  2,
#  3,
#  10,
#  10,
#  7,
#  2,
#  4,
#  2,
#  2,
#  1,
#  3,
#  1,
#  4,
#  1,
#  3,
#  2,
#  3,
#  4,
#  3,
#  4,
#  5,
#  2,
#  4,
#  2,
#  6,
#  3,
#  5,
#  1,
#  2,
#  2,
#  4,
#  3,
#  4,
#  5,
#  2,
#  3,
#  4,
#  2,
#  9,
#  1,
#  5,
#  4,
#  1,
#  5,
#  5,
#  3,
#  7,
#  5,
#  3,
#  3,
#  9,
#  3,
#  2,
#  1,
#  3,
#  4,
#  4,
#  4,
#  5,
#  3,
#  3,
#  5,
#  2,
#  3,
#  5,
#  1,
#  4,
#  4,
#  4,
#  6,
#  1,
#  3,
#  4,
#  7,
#  3,
#  4,
#  4,
#  6,
#  3,
#  8,
#  3,
#  3,
#  5,
#  1,
#  7,
#  7,
#  1,
#  3,
#  6,
#  8,
#  2,
#  4,
#  1,
#  8,
#  7,
#  1,
#  7,
#  1,
#  3,
#  7,
#  1,
#  7,
#  4,
#  6,
#  1,
#  4,
#  2,
#  6,
#  3,
#  10,
#  6,
#  8,
#  2,
#  5,
#  1,
#  2,
#  5,
#  6,
#  14,
#  7,
#  1,
#  8,
#  1,
#  1,
#  3,
#  3,
#  7,
#  5,
#  6,
#  2,
#  2,
#  7,
#  1,
#  1,
#  9,
#  6,
#  1,
#  4,
#  2,
#  5,
#  5,
#  3,
#  1,
#  3,
#  5,
#  5,
#  3,
#  4,
#  2,
#  2,
#  5,
#  2,
#  2,
#  3,
#  1,
#  1,
#  3,
#  3,
#  4,
#  3,
#  8,
#  1,
#  5,
#  4,
#  2,
#  7,
#  2,
#  5,
#  2,
#  2,
#  5,
#  1,
#  1,
#  5,
#  2,
#  3,
#  5,
#  1,
#  5,
#  2,
#  4,
#  9,
#  4,
#  4,
#  4,
#  4,
#  2,
#  4,
#  7,
#  2,
#  2,
#  6,
#  1,
#  1,
#  2,
#  4,
#  3,
#  1,
#  3,
#  4,
#  4,
#  3,
#  4,
#  1,
#  3,
#  5,
#  1,
#  3,
#  6,
#  5,
#  1,
#  5,
#  6,
#  9,
#  3,
#  8,
#  7,
#  1,
#  4,
#  9,
#  4,
#  7,
#  7,
#  1,
#  3,
#  2,
#  5,
#  4,
#  3,
#  6,
#  4,
#  2,
#  2,
#  3,
#  3,
#  2,
#  2,
#  6,
#  1,
#  3,
#  4,
#  5,
#  6,
#  7,
#  6,
#  6,
#  3,
#  5,
#  2,
#  4,
#  7,
#  1,
#  1,
#  5,
#  1,
#  2,
#  2,
#  5,
#  1,
#  4,
#  1,
#  2,
#  5,
#  1,
#  4,
#  2,
#  4,
#  3,
#  13,
#  4,
#  4,
#  5,
#  7,
#  2,
#  3,
#  1,
#  3,
#  9,
#  2,
#  3,
#  10,
#  4,
#  2,
#  3,
#  6,
#  2,
#  2,
#  7,
#  1,
#  1,
#  8,
#  1,
#  1,
#  6,
#  1,
#  1,
#  3,
#  6,
#  3,
#  8,
#  3,
#  4,
#  3,
#  3,
#  7,
#  6,
#  4,
#  3,
#  1,
#  5,
#  5,
#  3,
#  6,
#  3,
#  11,
#  6,
#  7,
#  1,
#  4,
#  2,
#  2,
#  4,
#  2,
#  6,
#  2,
#  4,
#  5,
#  2,
#  6,
#  2,
#  4,
#  2,
#  2,
#  7,
#  1,
#  1,
#  5,
#  1,
#  1,
#  8,
#  3,
#  2,
#  9,
#  3,
#  4,
#  2,
#  3,
#  3,
#  1,
#  4,
#  5,
#  7,
#  1,
#  5,
#  4,
#  6,
#  3,
#  5,
#  8,
#  2,
#  3,
#  3,
#  1,
#  8,
#  1,
#  5,
#  3,
#  6,
#  1,
#  3,
#  3,
#  2,
#  1,
#  4,
#  9,
#  4,
#  1,
#  3,
#  4,
#  4,
#  7,
#  2,
#  1,
#  4,
#  1,
#  7,
#  1,
#  7,
#  3,
#  5,
#  2,
#  3,
#  5,
#  1,
#  3,
#  7,
#  3,
#  3,
#  6,
#  3,
#  4,
#  1,
#  4,
#  2,
#  2,
#  5,
#  1,
#  1,
#  6,
#  1,
#  1,
#  3,
#  4,
#  7,
#  2,
#  1,
#  2,
#  7,
#  4,
#  7,
#  4,
#  4,
#  1,
#  4,
#  2,
#  8,
#  5,
#  1,
#  6,
#  1,
#  5,
#  3,
#  5,
#  2,
#  4,
#  5,
#  5,
#  3,
#  5,
#  5,
#  1,
#  2,
#  5,
#  2,
#  7,
#  4,
#  2,
#  3,
#  4,
#  1,
#  3,
#  3,
#  4,
#  6,
#  4,
#  7,
#  2,
#  3,
#  3,
#  7,
#  1,
#  2,
#  5,
#  4,
#  4,
#  5,
#  1,
#  5,
#  1,
#  4,
#  5,
#  5,
#  4,
#  1,
#  2,
#  ...]

# %%
[w.upper() for w in text1]
# Out:
# [u'[',
#  u'MOBY',
#  u'DICK',
#  u'BY',
#  u'HERMAN',
#  u'MELVILLE',
#  u'1851',
#  u']',
#  u'ETYMOLOGY',
#  u'.',
#  u'(',
#  u'SUPPLIED',
#  u'BY',
#  u'A',
#  u'LATE',
#  u'CONSUMPTIVE',
#  u'USHER',
#  u'TO',
#  u'A',
#  u'GRAMMAR',
#  u'SCHOOL',
#  u')',
#  u'THE',
#  u'PALE',
#  u'USHER',
#  u'--',
#  u'THREADBARE',
#  u'IN',
#  u'COAT',
#  u',',
#  u'HEART',
#  u',',
#  u'BODY',
#  u',',
#  u'AND',
#  u'BRAIN',
#  u';',
#  u'I',
#  u'SEE',
#  u'HIM',
#  u'NOW',
#  u'.',
#  u'HE',
#  u'WAS',
#  u'EVER',
#  u'DUSTING',
#  u'HIS',
#  u'OLD',
#  u'LEXICONS',
#  u'AND',
#  u'GRAMMARS',
#  u',',
#  u'WITH',
#  u'A',
#  u'QUEER',
#  u'HANDKERCHIEF',
#  u',',
#  u'MOCKINGLY',
#  u'EMBELLISHED',
#  u'WITH',
#  u'ALL',
#  u'THE',
#  u'GAY',
#  u'FLAGS',
#  u'OF',
#  u'ALL',
#  u'THE',
#  u'KNOWN',
#  u'NATIONS',
#  u'OF',
#  u'THE',
#  u'WORLD',
#  u'.',
#  u'HE',
#  u'LOVED',
#  u'TO',
#  u'DUST',
#  u'HIS',
#  u'OLD',
#  u'GRAMMARS',
#  u';',
#  u'IT',
#  u'SOMEHOW',
#  u'MILDLY',
#  u'REMINDED',
#  u'HIM',
#  u'OF',
#  u'HIS',
#  u'MORTALITY',
#  u'.',
#  u'"',
#  u'WHILE',
#  u'YOU',
#  u'TAKE',
#  u'IN',
#  u'HAND',
#  u'TO',
#  u'SCHOOL',
#  u'OTHERS',
#  u',',
#  u'AND',
#  u'TO',
#  u'TEACH',
#  u'THEM',
#  u'BY',
#  u'WHAT',
#  u'NAME',
#  u'A',
#  u'WHALE',
#  u'-',
#  u'FISH',
#  u'IS',
#  u'TO',
#  u'BE',
#  u'CALLED',
#  u'IN',
#  u'OUR',
#  u'TONGUE',
#  u'LEAVING',
#  u'OUT',
#  u',',
#  u'THROUGH',
#  u'IGNORANCE',
#  u',',
#  u'THE',
#  u'LETTER',
#  u'H',
#  u',',
#  u'WHICH',
#  u'ALMOST',
#  u'ALONE',
#  u'MAKETH',
#  u'THE',
#  u'SIGNIFICATION',
#  u'OF',
#  u'THE',
#  u'WORD',
#  u',',
#  u'YOU',
#  u'DELIVER',
#  u'THAT',
#  u'WHICH',
#  u'IS',
#  u'NOT',
#  u'TRUE',
#  u'."',
#  u'--',
#  u'HACKLUYT',
#  u'"',
#  u'WHALE',
#  u'.',
#  u'...',
#  u'SW',
#  u'.',
#  u'AND',
#  u'DAN',
#  u'.',
#  u'HVAL',
#  u'.',
#  u'THIS',
#  u'ANIMAL',
#  u'IS',
#  u'NAMED',
#  u'FROM',
#  u'ROUNDNESS',
#  u'OR',
#  u'ROLLING',
#  u';',
#  u'FOR',
#  u'IN',
#  u'DAN',
#  u'.',
#  u'HVALT',
#  u'IS',
#  u'ARCHED',
#  u'OR',
#  u'VAULTED',
#  u'."',
#  u'--',
#  u'WEBSTER',
#  u"'",
#  u'S',
#  u'DICTIONARY',
#  u'"',
#  u'WHALE',
#  u'.',
#  u'...',
#  u'IT',
#  u'IS',
#  u'MORE',
#  u'IMMEDIATELY',
#  u'FROM',
#  u'THE',
#  u'DUT',
#  u'.',
#  u'AND',
#  u'GER',
#  u'.',
#  u'WALLEN',
#  u';',
#  u'A',
#  u'.',
#  u'S',
#  u'.',
#  u'WALW',
#  u'-',
#  u'IAN',
#  u',',
#  u'TO',
#  u'ROLL',
#  u',',
#  u'TO',
#  u'WALLOW',
#  u'."',
#  u'--',
#  u'RICHARDSON',
#  u"'",
#  u'S',
#  u'DICTIONARY',
#  u'KETOS',
#  u',',
#  u'GREEK',
#  u'.',
#  u'CETUS',
#  u',',
#  u'LATIN',
#  u'.',
#  u'WHOEL',
#  u',',
#  u'ANGLO',
#  u'-',
#  u'SAXON',
#  u'.',
#  u'HVALT',
#  u',',
#  u'DANISH',
#  u'.',
#  u'WAL',
#  u',',
#  u'DUTCH',
#  u'.',
#  u'HWAL',
#  u',',
#  u'SWEDISH',
#  u'.',
#  u'WHALE',
#  u',',
#  u'ICELANDIC',
#  u'.',
#  u'WHALE',
#  u',',
#  u'ENGLISH',
#  u'.',
#  u'BALEINE',
#  u',',
#  u'FRENCH',
#  u'.',
#  u'BALLENA',
#  u',',
#  u'SPANISH',
#  u'.',
#  u'PEKEE',
#  u'-',
#  u'NUEE',
#  u'-',
#  u'NUEE',
#  u',',
#  u'FEGEE',
#  u'.',
#  u'PEKEE',
#  u'-',
#  u'NUEE',
#  u'-',
#  u'NUEE',
#  u',',
#  u'ERROMANGOAN',
#  u'.',
#  u'EXTRACTS',
#  u'(',
#  u'SUPPLIED',
#  u'BY',
#  u'A',
#  u'SUB',
#  u'-',
#  u'SUB',
#  u'-',
#  u'LIBRARIAN',
#  u').',
#  u'IT',
#  u'WILL',
#  u'BE',
#  u'SEEN',
#  u'THAT',
#  u'THIS',
#  u'MERE',
#  u'PAINSTAKING',
#  u'BURROWER',
#  u'AND',
#  u'GRUB',
#  u'-',
#  u'WORM',
#  u'OF',
#  u'A',
#  u'POOR',
#  u'DEVIL',
#  u'OF',
#  u'A',
#  u'SUB',
#  u'-',
#  u'SUB',
#  u'APPEARS',
#  u'TO',
#  u'HAVE',
#  u'GONE',
#  u'THROUGH',
#  u'THE',
#  u'LONG',
#  u'VATICANS',
#  u'AND',
#  u'STREET',
#  u'-',
#  u'STALLS',
#  u'OF',
#  u'THE',
#  u'EARTH',
#  u',',
#  u'PICKING',
#  u'UP',
#  u'WHATEVER',
#  u'RANDOM',
#  u'ALLUSIONS',
#  u'TO',
#  u'WHALES',
#  u'HE',
#  u'COULD',
#  u'ANYWAYS',
#  u'FIND',
#  u'IN',
#  u'ANY',
#  u'BOOK',
#  u'WHATSOEVER',
#  u',',
#  u'SACRED',
#  u'OR',
#  u'PROFANE',
#  u'.',
#  u'THEREFORE',
#  u'YOU',
#  u'MUST',
#  u'NOT',
#  u',',
#  u'IN',
#  u'EVERY',
#  u'CASE',
#  u'AT',
#  u'LEAST',
#  u',',
#  u'TAKE',
#  u'THE',
#  u'HIGGLEDY',
#  u'-',
#  u'PIGGLEDY',
#  u'WHALE',
#  u'STATEMENTS',
#  u',',
#  u'HOWEVER',
#  u'AUTHENTIC',
#  u',',
#  u'IN',
#  u'THESE',
#  u'EXTRACTS',
#  u',',
#  u'FOR',
#  u'VERITABLE',
#  u'GOSPEL',
#  u'CETOLOGY',
#  u'.',
#  u'FAR',
#  u'FROM',
#  u'IT',
#  u'.',
#  u'AS',
#  u'TOUCHING',
#  u'THE',
#  u'ANCIENT',
#  u'AUTHORS',
#  u'GENERALLY',
#  u',',
#  u'AS',
#  u'WELL',
#  u'AS',
#  u'THE',
#  u'POETS',
#  u'HERE',
#  u'APPEARING',
#  u',',
#  u'THESE',
#  u'EXTRACTS',
#  u'ARE',
#  u'SOLELY',
#  u'VALUABLE',
#  u'OR',
#  u'ENTERTAINING',
#  u',',
#  u'AS',
#  u'AFFORDING',
#  u'A',
#  u'GLANCING',
#  u'BIRD',
#  u"'",
#  u'S',
#  u'EYE',
#  u'VIEW',
#  u'OF',
#  u'WHAT',
#  u'HAS',
#  u'BEEN',
#  u'PROMISCUOUSLY',
#  u'SAID',
#  u',',
#  u'THOUGHT',
#  u',',
#  u'FANCIED',
#  u',',
#  u'AND',
#  u'SUNG',
#  u'OF',
#  u'LEVIATHAN',
#  u',',
#  u'BY',
#  u'MANY',
#  u'NATIONS',
#  u'AND',
#  u'GENERATIONS',
#  u',',
#  u'INCLUDING',
#  u'OUR',
#  u'OWN',
#  u'.',
#  u'SO',
#  u'FARE',
#  u'THEE',
#  u'WELL',
#  u',',
#  u'POOR',
#  u'DEVIL',
#  u'OF',
#  u'A',
#  u'SUB',
#  u'-',
#  u'SUB',
#  u',',
#  u'WHOSE',
#  u'COMMENTATOR',
#  u'I',
#  u'AM',
#  u'.',
#  u'THOU',
#  u'BELONGEST',
#  u'TO',
#  u'THAT',
#  u'HOPELESS',
#  u',',
#  u'SALLOW',
#  u'TRIBE',
#  u'WHICH',
#  u'NO',
#  u'WINE',
#  u'OF',
#  u'THIS',
#  u'WORLD',
#  u'WILL',
#  u'EVER',
#  u'WARM',
#  u';',
#  u'AND',
#  u'FOR',
#  u'WHOM',
#  u'EVEN',
#  u'PALE',
#  u'SHERRY',
#  u'WOULD',
#  u'BE',
#  u'TOO',
#  u'ROSY',
#  u'-',
#  u'STRONG',
#  u';',
#  u'BUT',
#  u'WITH',
#  u'WHOM',
#  u'ONE',
#  u'SOMETIMES',
#  u'LOVES',
#  u'TO',
#  u'SIT',
#  u',',
#  u'AND',
#  u'FEEL',
#  u'POOR',
#  u'-',
#  u'DEVILISH',
#  u',',
#  u'TOO',
#  u';',
#  u'AND',
#  u'GROW',
#  u'CONVIVIAL',
#  u'UPON',
#  u'TEARS',
#  u';',
#  u'AND',
#  u'SAY',
#  u'TO',
#  u'THEM',
#  u'BLUNTLY',
#  u',',
#  u'WITH',
#  u'FULL',
#  u'EYES',
#  u'AND',
#  u'EMPTY',
#  u'GLASSES',
#  u',',
#  u'AND',
#  u'IN',
#  u'NOT',
#  u'ALTOGETHER',
#  u'UNPLEASANT',
#  u'SADNESS',
#  u'--',
#  u'GIVE',
#  u'IT',
#  u'UP',
#  u',',
#  u'SUB',
#  u'-',
#  u'SUBS',
#  u'!',
#  u'FOR',
#  u'BY',
#  u'HOW',
#  u'MUCH',
#  u'THE',
#  u'MORE',
#  u'PAINS',
#  u'YE',
#  u'TAKE',
#  u'TO',
#  u'PLEASE',
#  u'THE',
#  u'WORLD',
#  u',',
#  u'BY',
#  u'SO',
#  u'MUCH',
#  u'THE',
#  u'MORE',
#  u'SHALL',
#  u'YE',
#  u'FOR',
#  u'EVER',
#  u'GO',
#  u'THANKLESS',
#  u'!',
#  u'WOULD',
#  u'THAT',
#  u'I',
#  u'COULD',
#  u'CLEAR',
#  u'OUT',
#  u'HAMPTON',
#  u'COURT',
#  u'AND',
#  u'THE',
#  u'TUILERIES',
#  u'FOR',
#  u'YE',
#  u'!',
#  u'BUT',
#  u'GULP',
#  u'DOWN',
#  u'YOUR',
#  u'TEARS',
#  u'AND',
#  u'HIE',
#  u'ALOFT',
#  u'TO',
#  u'THE',
#  u'ROYAL',
#  u'-',
#  u'MAST',
#  u'WITH',
#  u'YOUR',
#  u'HEARTS',
#  u';',
#  u'FOR',
#  u'YOUR',
#  u'FRIENDS',
#  u'WHO',
#  u'HAVE',
#  u'GONE',
#  u'BEFORE',
#  u'ARE',
#  u'CLEARING',
#  u'OUT',
#  u'THE',
#  u'SEVEN',
#  u'-',
#  u'STORIED',
#  u'HEAVENS',
#  u',',
#  u'AND',
#  u'MAKING',
#  u'REFUGEES',
#  u'OF',
#  u'LONG',
#  u'-',
#  u'PAMPERED',
#  u'GABRIEL',
#  u',',
#  u'MICHAEL',
#  u',',
#  u'AND',
#  u'RAPHAEL',
#  u',',
#  u'AGAINST',
#  u'YOUR',
#  u'COMING',
#  u'.',
#  u'HERE',
#  u'YE',
#  u'STRIKE',
#  u'BUT',
#  u'SPLINTERED',
#  u'HEARTS',
#  u'TOGETHER',
#  u'--',
#  u'THERE',
#  u',',
#  u'YE',
#  u'SHALL',
#  u'STRIKE',
#  u'UNSPLINTERABLE',
#  u'GLASSES',
#  u'!',
#  u'EXTRACTS',
#  u'.',
#  u'"',
#  u'AND',
#  u'GOD',
#  u'CREATED',
#  u'GREAT',
#  u'WHALES',
#  u'."',
#  u'--',
#  u'GENESIS',
#  u'.',
#  u'"',
#  u'LEVIATHAN',
#  u'MAKETH',
#  u'A',
#  u'PATH',
#  u'TO',
#  u'SHINE',
#  u'AFTER',
#  u'HIM',
#  u';',
#  u'ONE',
#  u'WOULD',
#  u'THINK',
#  u'THE',
#  u'DEEP',
#  u'TO',
#  u'BE',
#  u'HOARY',
#  u'."',
#  u'--',
#  u'JOB',
#  u'.',
#  u'"',
#  u'NOW',
#  u'THE',
#  u'LORD',
#  u'HAD',
#  u'PREPARED',
#  u'A',
#  u'GREAT',
#  u'FISH',
#  u'TO',
#  u'SWALLOW',
#  u'UP',
#  u'JONAH',
#  u'."',
#  u'--',
#  u'JONAH',
#  u'.',
#  u'"',
#  u'THERE',
#  u'GO',
#  u'THE',
#  u'SHIPS',
#  u';',
#  u'THERE',
#  u'IS',
#  u'THAT',
#  u'LEVIATHAN',
#  u'WHOM',
#  u'THOU',
#  u'HAST',
#  u'MADE',
#  u'TO',
#  u'PLAY',
#  u'THEREIN',
#  u'."',
#  u'--',
#  u'PSALMS',
#  u'.',
#  u'"',
#  u'IN',
#  u'THAT',
#  u'DAY',
#  u',',
#  u'THE',
#  u'LORD',
#  u'WITH',
#  u'HIS',
#  u'SORE',
#  u',',
#  u'AND',
#  u'GREAT',
#  u',',
#  u'AND',
#  u'STRONG',
#  u'SWORD',
#  u',',
#  u'SHALL',
#  u'PUNISH',
#  u'LEVIATHAN',
#  u'THE',
#  u'PIERCING',
#  u'SERPENT',
#  u',',
#  u'EVEN',
#  u'LEVIATHAN',
#  u'THAT',
#  u'CROOKED',
#  u'SERPENT',
#  u';',
#  u'AND',
#  u'HE',
#  u'SHALL',
#  u'SLAY',
#  u'THE',
#  u'DRAGON',
#  u'THAT',
#  u'IS',
#  u'IN',
#  u'THE',
#  u'SEA',
#  u'."',
#  u'--',
#  u'ISAIAH',
#  u'"',
#  u'AND',
#  u'WHAT',
#  u'THING',
#  u'SOEVER',
#  u'BESIDES',
#  u'COMETH',
#  u'WITHIN',
#  u'THE',
#  u'CHAOS',
#  u'OF',
#  u'THIS',
#  u'MONSTER',
#  u"'",
#  u'S',
#  u'MOUTH',
#  u',',
#  u'BE',
#  u'IT',
#  u'BEAST',
#  u',',
#  u'BOAT',
#  u',',
#  u'OR',
#  u'STONE',
#  u',',
#  u'DOWN',
#  u'IT',
#  u'GOES',
#  u'ALL',
#  u'INCONTINENTLY',
#  u'THAT',
#  u'FOUL',
#  u'GREAT',
#  u'SWALLOW',
#  u'OF',
#  u'HIS',
#  u',',
#  u'AND',
#  u'PERISHETH',
#  u'IN',
#  u'THE',
#  u'BOTTOMLESS',
#  u'GULF',
#  u'OF',
#  u'HIS',
#  u'PAUNCH',
#  u'."',
#  u'--',
#  u'HOLLAND',
#  u"'",
#  u'S',
#  u'PLUTARCH',
#  u"'",
#  u'S',
#  u'MORALS',
#  u'.',
#  u'"',
#  u'THE',
#  u'INDIAN',
#  u'SEA',
#  u'BREEDETH',
#  u'THE',
#  u'MOST',
#  u'AND',
#  u'THE',
#  u'BIGGEST',
#  u'FISHES',
#  u'THAT',
#  u'ARE',
#  u':',
#  u'AMONG',
#  u'WHICH',
#  u'THE',
#  u'WHALES',
#  u'AND',
#  u'WHIRLPOOLES',
#  u'CALLED',
#  u'BALAENE',
#  u',',
#  u'TAKE',
#  u'UP',
#  u'AS',
#  u'MUCH',
#  u'IN',
#  u'LENGTH',
#  u'AS',
#  u'FOUR',
#  u'ACRES',
#  u'OR',
#  u'ARPENS',
#  u'OF',
#  u'LAND',
#  u'."',
#  u'--',
#  u'HOLLAND',
#  u"'",
#  u'S',
#  u'PLINY',
#  u'.',
#  u'"',
#  u'SCARCELY',
#  u'HAD',
#  u'WE',
#  u'PROCEEDED',
#  u'TWO',
#  u'DAYS',
#  u'ON',
#  u'THE',
#  u'SEA',
#  u',',
#  u'WHEN',
#  u'ABOUT',
#  u'SUNRISE',
#  u'A',
#  u'GREAT',
#  u'MANY',
#  u'WHALES',
#  u'AND',
#  u'OTHER',
#  u'MONSTERS',
#  u'OF',
#  u'THE',
#  u'SEA',
#  u',',
#  u'APPEARED',
#  u'.',
#  u'AMONG',
#  u'THE',
#  u'FORMER',
#  u',',
#  u'ONE',
#  u'WAS',
#  u'OF',
#  u'A',
#  u'MOST',
#  u'MONSTROUS',
#  u'SIZE',
#  u'.',
#  u'...',
#  u'THIS',
#  u'CAME',
#  u'TOWARDS',
#  u'US',
#  u',',
#  u'OPEN',
#  u'-',
#  u'MOUTHED',
#  u',',
#  u'RAISING',
#  u'THE',
#  u'WAVES',
#  u'ON',
#  u'ALL',
#  u'SIDES',
#  u',',
#  u'AND',
#  u'BEATING',
#  u'THE',
#  u'SEA',
#  u'BEFORE',
#  u'HIM',
#  u'INTO',
#  u'A',
#  u'FOAM',
#  u'."',
#  u'--',
#  u'TOOKE',
#  u"'",
#  u'S',
#  u'LUCIAN',
#  u'.',
#  u'"',
#  u'THE',
#  u'TRUE',
#  u'HISTORY',
#  u'."',
#  u'"',
#  u'HE',
#  u'VISITED',
#  u'THIS',
#  u'COUNTRY',
#  u'ALSO',
#  u'WITH',
#  u'A',
#  u'VIEW',
#  u'OF',
#  u'CATCHING',
#  u'HORSE',
#  u'-',
#  u'WHALES',
#  u',',
#  u'WHICH',
#  u'HAD',
#  u'BONES',
#  u'OF',
#  u'VERY',
#  u'GREAT',
#  u'VALUE',
#  u'FOR',
#  u'THEIR',
#  u'TEETH',
#  u',',
#  u'OF',
#  u'WHICH',
#  u'HE',
#  u'BROUGHT',
#  u'SOME',
#  u'TO',
#  u'THE',
#  u'KING',
#  u'.',
#  u'...',
#  u'THE',
#  u'BEST',
#  u'WHALES',
#  u'WERE',
#  u'CATCHED',
#  u'IN',
#  u'HIS',
#  u'OWN',
#  u'COUNTRY',
#  u',',
#  u'OF',
#  u'WHICH',
#  u'SOME',
#  u'WERE',
#  u'FORTY',
#  u'-',
#  u'EIGHT',
#  u',',
#  u'SOME',
#  u'FIFTY',
#  u'YARDS',
#  u'LONG',
#  u'.',
#  u'HE',
#  ...]

# %%
for word in ['Call', 'me', 'Ishmael', '.']:
    print word
# Out:
# Call
# me
# Ishmael
# .

# %%
sent1 = ['Call', 'me', 'Ishmael', '.']

# %%
for xyzzy in sent1:
    if xyzzy.endswith('l'):
        print xyzzy
# Out:
# Call
# Ishmael
