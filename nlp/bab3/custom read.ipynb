# %%
from __future__ import division
from nltk.book import *
from __future__ import division
import nltk
import numpy
import matplotlib
import nltk, re, pprint
from urllib import urlopen
import sys
#reload(sys)                       <----- activate this for reading 
#sys.setdefaultencoding('utf8')

from bs4 import BeautifulSoup
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
url = "https://kbbi.kata.web.id/kelas-kata/kata-benda/"

# %%
html_doc = urlopen(url).read()
soup = BeautifulSoup(html_doc, 'html.parser')
raw = soup.get_text()
tokens = nltk.word_tokenize(raw)
text = nltk.Text(tokens)

# %%
text.concordance('abakus')
# Out:
# Displaying 1 of 1 matches:
# a dibuat tali belati ; Musa textilis abakus aba.kusNomina ( kata benda ) dekak-d

# %%
tokens
# Out:
# [u'Daftar',
#  u'Kata',
#  u'Benda',
#  u'(',
#  u'Nomina',
#  u')',
#  u'dalam',
#  u'Bahasa',
#  u'Indonesia',
#  u'Kamus',
#  u'KBBI',
#  u'Online',
#  u',',
#  u'Makna',
#  u'Kata',
#  u'dari',
#  u'Kamus',
#  u'Besar',
#  u'Bahasa',
#  u'Indonesia',
#  u'img',
#  u'#',
#  u'wpstats',
#  u'{',
#  u'display',
#  u':',
#  u'none',
#  u'}',
#  u'.add',
#  u'{',
#  u'margin:20px',
#  u';',
#  u'min-height:90px',
#  u';',
#  u'text-align',
#  u':',
#  u'center',
#  u'}',
#  u'.adsbygoogle',
#  u'{',
#  u'margin-left',
#  u':',
#  u'auto',
#  u';',
#  u'margin-right',
#  u':',
#  u'auto',
#  u';',
#  u'}',
#  u'@',
#  u'media',
#  u'(',
#  u'min-width:768px',
#  u')',
#  u'{',
#  u'.add-top',
#  u'.adsbygoogle',
#  u'{',
#  u'height:90px',
#  u';',
#  u'width:728px',
#  u';',
#  u'}',
#  u'.add-content',
#  u'.adsbygoogle',
#  u'{',
#  u'width:336px',
#  u';',
#  u'height:280px',
#  u';',
#  u'}',
#  u'.add-content-top',
#  u'.adsbygoogle',
#  u'{',
#  u'width:468px',
#  u';',
#  u'height:60px',
#  u';',
#  u'}',
#  u'}',
#  u'@',
#  u'media',
#  u'(',
#  u'max-width:768px',
#  u')',
#  u'{',
#  u'.add',
#  u'.adsbygoogle',
#  u'{',
#  u'width:336px',
#  u';',
#  u'height:280px',
#  u';',
#  u'}',
#  u'}',
#  u'@',
#  u'media',
#  u'(',
#  u'max-width:360px',
#  u')',
#  u'{',
#  u'.add',
#  u'{',
#  u'margin-left',
#  u':',
#  u'auto',
#  u';',
#  u'margin-right',
#  u':',
#  u'auto',
#  u';',
#  u'}',
#  u'.add',
#  u'.adsbygoogle',
#  u'{',
#  u'width:300px',
#  u';',
#  u'height:250px',
#  u';',
#  u'}',
#  u'}',
#  u'(',
#  u'function',
#  u'(',
#  u'i',
#  u',',
#  u's',
#  u',',
#  u'o',
#  u',',
#  u'g',
#  u',',
#  u'r',
#  u',',
#  u'a',
#  u',',
#  u'm',
#  u')',
#  u'{',
#  u'i',
#  u'[',
#  u"'GoogleAnalyticsObject",
#  u"'",
#  u']',
#  u'=r',
#  u';',
#  u'i',
#  u'[',
#  u'r',
#  u']',
#  u'=i',
#  u'[',
#  u'r',
#  u']',
#  u'||function',
#  u'(',
#  u')',
#  u'{',
#  u'(',
#  u'i',
#  u'[',
#  u'r',
#  u']',
#  u'.q=i',
#  u'[',
#  u'r',
#  u']',
#  u'.q||',
#  u'[',
#  u']',
#  u')',
#  u'.push',
#  u'(',
#  u'arguments',
#  u')',
#  u'}',
#  u',',
#  u'i',
#  u'[',
#  u'r',
#  u']',
#  u'.l=1*new',
#  u'Date',
#  u'(',
#  u')',
#  u';',
#  u'a=s.createElement',
#  u'(',
#  u'o',
#  u')',
#  u',',
#  u'm=s.getElementsByTagName',
#  u'(',
#  u'o',
#  u')',
#  u'[',
#  u'0',
#  u']',
#  u';',
#  u'a.async=1',
#  u';',
#  u'a.src=g',
#  u';',
#  u'm.parentNode.insertBefore',
#  u'(',
#  u'a',
#  u',',
#  u'm',
#  u')',
#  u'}',
#  u')',
#  u'(',
#  u'window',
#  u',',
#  u'document',
#  u',',
#  u"'script",
#  u"'",
#  u',',
#  u"'https",
#  u':',
#  u'//www.google-analytics.com/analytics.js',
#  u"'",
#  u',',
#  u"'ga",
#  u"'",
#  u')',
#  u';',
#  u'ga',
#  u'(',
#  u"'create",
#  u"'",
#  u',',
#  u"'UA-78439326-3",
#  u"'",
#  u',',
#  u"'auto",
#  u"'",
#  u')',
#  u';',
#  u'ga',
#  u'(',
#  u"'send",
#  u"'",
#  u',',
#  u"'pageview",
#  u"'",
#  u')',
#  u';',
#  u'Toggle',
#  u'navigation',
#  u'KAMUS',
#  u'Kategori',
#  u'Kata',
#  u'Peribahasa',
#  u'Kelas',
#  u'Kata',
#  u'Kata',
#  u'Benda',
#  u'(',
#  u'Nomina',
#  u')',
#  u'Kata',
#  u'Bilangan',
#  u'(',
#  u'Numeralia',
#  u')',
#  u'Kata',
#  u'Ganti',
#  u'(',
#  u'Pronomina',
#  u')',
#  u'Kata',
#  u'Kerja',
#  u'(',
#  u'Verba',
#  u')',
#  u'Kata',
#  u'Keterangan',
#  u'(',
#  u'Adverbia',
#  u')',
#  u'Kata',
#  u'Sifat',
#  u'(',
#  u'Adjektiva',
#  u')',
#  u'Kata',
#  u'Tugas',
#  u'(',
#  u'Partikel',
#  u')',
#  u'Ragam',
#  u'Bahasa',
#  u'Cakapan',
#  u'(',
#  u'Tidak',
#  u'Baku',
#  u')',
#  u'Arkais',
#  u'(',
#  u'Tidak',
#  u'Lazim',
#  u')',
#  u'Klasik',
#  u'Kasar',
#  u'Hormat',
#  u'Dialek',
#  u'Melayu',
#  u'Melayu',
#  u'Jakarta',
#  u'Bidang',
#  u'Ilmu',
#  u'Administrasi',
#  u'dan',
#  u'Kepegawaian',
#  u'Agama',
#  u'Budha',
#  u'Agama',
#  u'Hindu',
#  u'Agama',
#  u'Islam',
#  u'Agama',
#  u'Katolik',
#  u'Agama',
#  u'Kristen',
#  u'Anatomi',
#  u'Antropologi',
#  u'Arkeologi',
#  u'Arsitektur',
#  u'Astrologi',
#  u'Astronomi',
#  u'Bakteriologi',
#  u'Biologi',
#  u'Botani',
#  u'Demografi',
#  u'Ekonomi',
#  u'dan',
#  u'Keuangan',
#  u'Elektronika',
#  u'Entomologi',
#  u'Farmasi',
#  u'Filologi',
#  u'Filsafat',
#  u'Fisika',
#  u'Geografi',
#  u'dan',
#  u'Geologi',
#  u'Grafika',
#  u'Hidrologi',
#  u'Hidrometeorologi',
#  u'Hukum',
#  u'Ilmu',
#  u'Komunikasi',
#  u'Kedirgantaraan',
#  u'Kedokteran',
#  u'dan',
#  u'Fisiologi',
#  u'Kehutanan',
#  u'Kemiliteran',
#  u'Kesenian',
#  u'Kimia',
#  u'Komputer',
#  u'Linguistik',
#  u'Manajemen',
#  u'Matematika',
#  u'Mekanika',
#  u'Metalurgi',
#  u'Meteorologi',
#  u'Mikologi',
#  u'Mineralogi',
#  u'Musik',
#  u'Olahraga',
#  u'Pelayaran',
#  u'Pendidikan',
#  u'Penerbangan',
#  u'Perdagangan',
#  u'Tentang',
#  u'Tentang',
#  u'Kamus',
#  u'Cara',
#  u'Penggunaan',
#  u'ACAK',
#  u'A',
#  u'B',
#  u'C',
#  u'D',
#  u'E',
#  u'F',
#  u'G',
#  u'H',
#  u'I',
#  u'J',
#  u'K',
#  u'L',
#  u'M',
#  u'N',
#  u'O',
#  u'P',
#  u'Q',
#  u'R',
#  u'S',
#  u'T',
#  u'U',
#  u'V',
#  u'W',
#  u'X',
#  u'Y',
#  u'Z',
#  u'atOptions',
#  u'=',
#  u'{',
#  u"'key",
#  u"'",
#  u':',
#  u"'83ecd352237efe049fba3b1ccb6b2ebc",
#  u"'",
#  u',',
#  u"'format",
#  u"'",
#  u':',
#  u"'iframe",
#  u"'",
#  u',',
#  u"'height",
#  u"'",
#  u':',
#  u'250',
#  u',',
#  u"'width",
#  u"'",
#  u':',
#  u'300',
#  u',',
#  u"'params",
#  u"'",
#  u':',
#  u'{',
#  u'}',
#  u'}',
#  u';',
#  u'document.write',
#  u'(',
#  u"'",
#  u'<',
#  u'scr',
#  u"'",
#  u'+',
#  u"'ipt",
#  u'type=',
#  u"''",
#  u'text/javascript',
#  u"''",
#  u'src=',
#  u"''",
#  u'http',
#  u"'",
#  u'+',
#  u'(',
#  u'location.protocol',
#  u'===',
#  u"'https",
#  u':',
#  u"'",
#  u'?',
#  u"'s",
#  u"'",
#  u':',
#  u'``',
#  u')',
#  u'+',
#  u"'",
#  u':',
#  u'//www.bnserving.com/invoke.js',
#  u"''",
#  u'>',
#  u'<',
#  u'/scr',
#  u"'",
#  u'+',
#  u"'ipt",
#  u'>',
#  u"'",
#  u')',
#  u';',
#  u'Cari',
#  u'!',
#  u'Daftar',
#  u'Kata',
#  u'Benda',
#  u'(',
#  u'Nomina',
#  u')',
#  u'dalam',
#  u'Bahasa',
#  u'Indonesia',
#  u'(',
#  u'ke',
#  u')',
#  u'robohan',
#  u'(',
#  u'ke',
#  u')',
#  u'ro.boh.anNomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'runtuhan',
#  u';',
#  u'reruntuhan',
#  u';',
#  u'puing',
#  u'(',
#  u'ke',
#  u')',
#  u'tikan',
#  u'(',
#  u'ke',
#  u')',
#  u'.tik.anNomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'yang',
#  u';',
#  u'hasil',
#  u'mengetik',
#  u':',
#  u'(',
#  u'ke',
#  u')',
#  u'tikan',
#  u'nya',
#  u'rapi',
#  u'aba',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'ayah',
#  u';',
#  u'bapak',
#  u'abad',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'(',
#  u'1',
#  u')',
#  u'masa',
#  u'seratus',
#  u'tahun',
#  u':',
#  u'bangunan',
#  u'itu',
#  u'diperkirakan',
#  u'dapat',
#  u'bertahan',
#  u'satu',
#  u'abad',
#  u';',
#  u'(',
#  u'2',
#  u')',
#  u'jangka',
#  u'waktu',
#  u'yang',
#  u'lamanya',
#  u'seratus',
#  u'tahun',
#  u':',
#  u'abad',
#  u'ke-20',
#  u'mulai',
#  u'pada',
#  u'tahun',
#  u'1901',
#  u'sampai',
#  u'tahun',
#  u'2000',
#  u';',
#  u'(',
#  u'3',
#  u')',
#  u'zaman',
#  u'(',
#  u'yang',
#  u'lamanya',
#  u'tidak',
#  u'tentu',
#  u')',
#  u';',
#  u'(',
#  u'4',
#  u')',
#  u'masa',
#  u'yang',
#  u'kekal',
#  u',',
#  u'tidak',
#  u'berkesudahan',
#  u'abadiah',
#  u'aba.di.ahBerasal',
#  u'dari',
#  u'bahasa',
#  u'Arab',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'kekekalan',
#  u'abaimana',
#  u'abai.ma.naArkais',
#  u'(',
#  u'tidak',
#  u'lazim',
#  u')',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'(',
#  u'1',
#  u')',
#  u'lubang',
#  u'pelepasan',
#  u';',
#  u'dubur',
#  u';',
#  u'(',
#  u'2',
#  u')',
#  u'kemaluan',
#  u'abaka',
#  u'aba.ka',
#  u'tumbuhan',
#  u'yang',
#  u'seratnya',
#  u'dibuat',
#  u'tali',
#  u'belati',
#  u';',
#  u'Musa',
#  u'textilis',
#  u'abakus',
#  u'aba.kusNomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'dekak-dekak',
#  u';',
#  u'swipoa',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'Istilah',
#  u'arsitektur',
#  u'lempeng',
#  u'datar',
#  u'di',
#  u'atas',
#  u'kepala',
#  u'tiang',
#  u'dengan',
#  u'pinggiran',
#  u'cekung',
#  u'atau',
#  u'beralur',
#  u'aban',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'Istilah',
#  u'antropologi',
#  u'sebutan',
#  u'bagi',
#  u'duda',
#  u'dalam',
#  u'masyarakat',
#  u'Dayak',
#  u'Kayan',
#  u'abangan',
#  u'abang.anBerasal',
#  u'dari',
#  u'bahasa',
#  u'Jawa',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'golongan',
#  u'masyarakat',
#  u'yang',
#  u'menganut',
#  u'agama',
#  u'Islam',
#  u',',
#  u'tetapi',
#  u'tidak',
#  u'melaksanakan',
#  u'ajaran',
#  u'secara',
#  u'keseluruhan',
#  u'Nomina',
#  u'(',
#  u'kata',
#  u'benda',
#  u')',
#  u'talang',
#  u'air',
#  u'pada',
#  u'atap',
#  u'rumah',
#  u'dan',
#  u'sebagainya',
#  u'Posts',
#  u'navigation',
#  u'1',
#  u'2',
#  u'\u2026',
#  u'1,943',
#  u'Next',
#  u'\u2192',
#  u'Kata',
#  u'Acak',
#  u'garebek',
#  u'dabak',
#  u'ketimus',
#  u'gelinjang',
#  u'lada',
#  u'putih',
#  u'biduk',
#  u'tiris',
#  u'menanti',
#  u'karam',
#  u'senapan',
#  u'bambu',
#  u'megatren',
#  u'memensiun',
#  u'kampit',
#  u'KATEGORI',
#  u'Kata',
#  u'Peribahasa',
#  u'KELAS',
#  u'KATA',
#  u'Kata',
#  u'Benda',
#  u'(',
#  u'Nomina',
#  u')',
#  u'Kata',
#  u'Kerja',
#  u'(',
#  u'Verba',
#  u')',
#  u'Kata',
#  u'Sifat',
#  u'(',
#  u'Adjektiva',
#  u')',
#  u'Kata',
#  u'Keterangan',
#  u'(',
#  u'Adverbia',
#  u')',
#  u'Kata',
#  u'Tugas',
#  u'(',
#  u'Partikel',
#  u')',
#  u'Kata',
#  u'Bilangan',
#  u'(',
#  u'Numeralia',
#  u')',
#  u'Kata',
#  u'Ganti',
#  u'(',
#  u'Pronomina',
#  u')',
#  u'RAGAM',
#  u'BAHASA',
#  u'Cakapan',
#  u'(',
#  u'Tidak',
#  u'Baku',
#  u')',
#  u'Arkais',
#  u'(',
#  u'Tidak',
#  u'Lazim',
#  u')',
#  u'Klasik',
#  u'Kasar',
#  u'Hormat',
#  u'DIALEK',
#  u'Melayu',
#  u'Jakarta',
#  u'BIDANG',
#  u'ILMU',
#  u'Linguistik',
#  u'Kimia',
#  u'Kedokteran',
#  u'dan',
#  u'Fisiologi',
#  u'Biologi',
#  u'Fisika',
#  u'Geografi',
#  u'dan',
#  u'Geologi',
#  u'Pelayaran',
#  u'Agama',
#  u'Islam',
#  u'Sastra',
#  u'Hukum',
#  u'Olahraga',
#  u'Ekonomi',
#  u'dan',
#  u'Keuangan',
#  u'Anatomi',
#  u'Meteorologi',
#  u'Matematika',
#  u'Zoologi',
#  u'Botani',
#  u'Psikologi',
#  u'Pertanian',
#  u'Peternakan',
#  u'Antropologi',
#  u'Politik',
#  u'dan',
#  u'Pemerintahan',
#  u'Teknik',
#  u'Agama',
#  u'Katolik',
#  u'Kesenian',
#  u'Grafika',
#  u'Ilmu',
#  u'Komunikasi',
#  u'Elektronika',
#  u'Agama',
#  u'Kristen',
#  u'Musik',
#  u'Farmasi',
#  u'Perkapalan',
#  u'Manajemen',
#  u'Arkeologi',
#  u'Administrasi',
#  u'dan',
#  u'Kepegawaian',
#  u'Pendidikan',
#  u'Perdagangan',
#  u'Mineralogi',
#  u'Petrologi',
#  u'serta',
#  u'Minyak',
#  u'dan',
#  u'Gas',
#  u'Bumi',
#  u'Kemiliteran',
#  u'Perikanan',
#  u'Astronomi',
#  u'Sosiologi',
#  u'Hidrologi',
#  u'Demografi',
#  u'Astrologi',
#  u'Agama',
#  u'Hindu',
#  u'Statistik',
#  u'Komputer',
#  u'Kehutanan',
#  u'Tasawuf',
#  u'Hidrometeorologi',
#  u'Filsafat',
#  u'Mikologi',
#  u'Filologi',
#  u'Perindustrian',
#  u'dan',
#  u'Kerajinan',
#  u'Arsitektur',
#  u'Agama',
#  u'Budha',
#  u'Metalurgi',
#  u'Bakteriologi',
#  u'Entomologi',
#  u'Telekomunikasi',
#  u'ASAL',
#  u'BAHASA',
#  u'Jawa',
#  u'Minangkabau',
#  u'Arab',
#  u'Sunda',
#  u'Cina',
#  u'Belanda',
#  u'Bali',
#  u'Sansekerta',
#  u'Jepang',
#  u'malaysia',
#  u'Batak',
#  u'Inggris',
#  u'Latin',
#  u'Palembang',
#  u'Dayak',
#  u'Minahasa',
#  u'Lampung',
#  u'Madura',
#  u'Menado',
#  u'Italia',
#  u'Portugis',
#  u'Kamus',
#  u'KBBI',
#  u'(',
#  u'Kamus',
#  u'Besar',
#  u'Bahasa',
#  u'Indonesia',
#  u'Online',
#  u')',
#  u'_stq',
#  u'=',
#  u'window._stq',
#  u'||',
#  u'[',
#  u']',
#  u';',
#  u'_stq.push',
#  u'(',
#  u'[',
#  u"'view",
#  u"'",
#  u',',
#  u'{',
#  u'v',
#  u':',
#  u"'ext",
#  u"'",
#  u',',
#  u'j',
#  u':',
#  u"'1:6.5",
#  u"'",
#  u',',
#  u'blog',
#  u':',
#  u"'120800840",
#  u"'",
#  u',',
#  u'post',
#  u':',
#  u"'0",
#  u"'",
#  u',',
#  u'tz',
#  u':',
#  u"'7",
#  u"'",
#  u',',
#  u'srv',
#  u':',
#  u"'kbbi.kata.web.id",
#  u"'",
#  u'}',
#  u']',
#  u')',
#  u';',
#  u'_stq.push',
#  u'(',
#  u'[',
#  u"'clickTrackerInit",
#  u"'",
#  u',',
#  u"'120800840",
#  u"'",
#  u',',
#  u"'0",
#  u"'",
#  u']',
#  u')',
#  u';']

# %%
text
# Out:
# <Text: Daftar Kata Benda ( Nomina ) dalam Bahasa...>
